# %% [markdown]
# # A simple Perceptron in NumPy

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs #for data generatio

# %%
X, y = make_blobs(n_samples=100, centers=2, n_features=2,center_box=(2,10),random_state=42)

# %%
plt.scatter(X[:,0],X[:,1],c=y)

# %% [markdown]
# ## Parameterize the classifier hyper-plane
# * find offset $b$ and slope $w$

# %%
#helper function to find parameters
def abline(slope, intercept):
    """Plot a line from slope and intercept"""
    axes = plt.gca()
    x_vals = np.array(axes.get_xlim())
    y_vals = intercept + slope * x_vals
    plt.plot(x_vals, y_vals, '--')

# %%
plt.scatter(X[:,0],X[:,1],c=y)
#abline(slope,offset)

# %%
#set parameter
b= 1
w= np.array([1,-1])

# %%
#check if othorgonal
w.dot(np.array([1,1]))
# Out:
# 0

# %%
plt.scatter(X[:,0],X[:,1],c=y)
plt.colorbar()
abline(1,2)
plt.quiver(6,8,w[0],w[1])

# %% [markdown]
# ### Classify samples via $sgn(wx+b)$

# %%
y = (y+2-1)
y
# Out:
# array([1, 2, 1, 2, 2, 1, 2, 2, 1, 1, 1, 2, 1, 1, 2, 2, 2, 2, 2, 1, 2, 2,
#        2, 2, 2, 1, 2, 1, 2, 2, 1, 1, 1, 1, 1, 2, 2, 1, 1, 1, 1, 2, 2, 2,
#        2, 1, 1, 1, 1, 2, 2, 1, 1, 2, 1, 2, 1, 2, 2, 1, 1, 2, 1, 2, 2, 2,
#        2, 1, 2, 2, 1, 2, 2, 2, 2, 2, 2, 1, 2, 1, 2, 1, 1, 1, 2, 1, 1, 1,
#        2, 1, 2, 1, 1, 1, 1, 1, 1, 2, 1, 1])

# %% [markdown]
# ### classify single sample

# %%
print(np.sign(w.dot(X[1].T)+b))
print(y[1])
# Out:
# 1.0
# 2

# %% [markdown]
# ### classify all samples at once
# * change vector dot-product to vector matrix mult (matrix holds all samples)
# * check results

# %%
pos = np.where(y!=np.sign(w.dot(X[1].T)+b))
pos
# Out:
# (array([ 1,  3,  4,  6,  7, 11, 14, 15, 16, 17, 18, 20, 21, 22, 23, 24, 26,
#         28, 29, 35, 36, 41, 42, 43, 44, 49, 50, 53, 55, 57, 58, 61, 63, 64,
#         65, 66, 68, 69, 71, 72, 73, 74, 75, 76, 78, 80, 84, 88, 90, 97]),)

# %%
y_test = y
y_test[pos]= 2
plt.scatter(X[:,0],X[:,1],c =y_test)
plt.colorbar()
abline(1,2)
